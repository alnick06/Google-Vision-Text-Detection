# %%
import base64
import os
import re
import sys

from googleapiclient import discovery
from googleapiclient import errors
import nltk
from nltk.stem.snowball import EnglishStemmer
from oauth2client.client import GoogleCredentials
import redis
import io
from google.cloud import vision
from google.cloud.vision import types
from google.oauth2 import service_account
import json

service_account_info = json.load(open('/Users/alnick06/gcloudstuff/goodapikey.json'))
credentials = service_account.Credentials.from_service_account_info(service_account_info)


client = vision.ImageAnnotatorClient(credentials=credentials)
file_name = '/Users/alnick06/gcloudstuff/RLMS_Survey.JPEG'

# for page in response.full_text_annotation.pages:
#     for block in page.blocks:
#         print('\nBlock confidence: {}\n'.format(block.confidence))

#         for paragraph in block.paragraphs:
#             print('Paragraph confidence: {}'.format(
#                 paragraph.confidence))

#             for word in paragraph.words:
#                 word_text = ''.join([
#                     symbol.text for symbol in word.symbols
#                 ])
#                 print('Word text: {} (confidence: {})'.format(
#                     word_text, word.confidence))

#                 for symbol in word.symbols:
#                     print('\tSymbol: {} (confidence: {})'.format(
#                         symbol.text, symbol.confidence))

with io.open(file_name, 'rb') as image_file:
    content = image_file.read()
image = types.Image(content=content)

response = client.text_detection(image=image)
texts = response.text_annotations

for text in texts:
    print('\n"{}"'.format(text.description))
# Out:
# "Paving flieWay
# OUNDATION
# Paving The Way Foundation Feedback ©
# 1. Which of these is human trafficking? (Circle all that apply)
# (a. Modern Day Slavery
# b. People being forced to work in fields picking food
# People being held against their will
# (d. People being forced to do something they don't want to
# eBeing paid for sex and not keeping the money
# f. People selling things door to door
# 2. How can it happen? (Circle all that apply)
# a. Runaways
# Kidnapped
# Being Recruited by someone they are dating
# Friends
# e)Trusting the wrong people
# f. Via Social Media
# g. Other:
# 3. Where does Florida Rank in the US for human trafficking? (Circle only one)
# a. Number 1
# ⓑ Top 5
# c. Top 10
# d. Top 20
# e. Top 30
# f. Last
# 4. Where do you think Orlando Ranks in the State of Florida for human trafficking?
# (Circle only one)
# st
# nd
# rd
# 2
# d. 5th
# e. 10th
# f. Last
# 5. Where can people can be recruited into trafficking? (Circle all that apply)
# a. School
# ...

# %% [markdown]
# # The results don't seem to be consistent enough to apply this method to 600 inputting handwritten surveys. The formatting is off and the Google Vision is not picking up the handwriteen aspect of the survey.
